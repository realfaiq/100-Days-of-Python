# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('C:/Users/Dell/Desktop/data-set/Parks.csv')

# %%
df
# Out:
#                                       site_name
# 0    Bennington Battlefield State Historic Site  \
# 1                  Clermont State Historic Site
# 2             Clinton House State Historic Site
# 3                    Crailo State Historic Site
# 4               Crown Point State Historic Site
# ..                                          ...
# 226                        Whirlpool State Park
# 227                         Wildwood State Park
# 228                 Wilson-Tuscarora State Park
# 229                      Wonder Lake State Park
# 230                   Woodlawn Beach State Park
#
#                                     website   latitude  longitude
# 0    https://parks.ny.gov/historic-sites/12  42.933758 -73.304878  \
# 1    https://parks.ny.gov/historic-sites/16  42.085087 -73.911835
# 2     https://parks.ny.gov/historic-sites/1  41.700333 -73.915993
# 3    https://parks.ny.gov/historic-sites/30  42.634590 -73.749496
# ...

# %%
plt.figure(figsize = (8,5))
plt.title('Parks in Newyork')
plt.plot(df['site_name'], df['latitude'], 'b.-', label = 'Parks according to latitude')
plt.plot(df['site_name'], df['longitude'], 'r--', label = 'Parks according to longitude')
plt.xlabel('site_name')
plt.ylabel('latitude')
plt.legend()
plt.show()

# %%
latitude = df['latitude'].count()
longitude = df['longitude'].count()
labels = ['Latitude', 'Longitude']
plt.pie([latitude, longitude], labels = labels, colors = ['red', 'purple'], autopct = '%.2f %%')
plt.title('Parks according to latitude and longitude')
plt.show()

# %%
sns.countplot(x = df['latitude'], data = df, palette = 'Set2')
plt.show()

# %%
sns.barplot(x = df['latitude'], y = df['longitude'])
plt.show()

# %%
sns.scatterplot(x = df['latitude'], y = df['longitude'], data = df)
plt.show()
